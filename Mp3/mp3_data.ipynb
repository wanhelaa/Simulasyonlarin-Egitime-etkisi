# %%
Yöntem: Doküman / İçerik Analizi (Nicel Veri Çıkarımı),Yapay Veri
Veri Kaynağı: 6 farklı akademik makale (Dergipark, SAGE, BMC, Springer),Yapay Veri
Kayıt Sayısı: 10 satır.

# %%
import pandas as pd
df = pd.read_csv('data_mp3.csv')
print("Verinin İlk Satırları:")
print(df.head())
# Out:
# Verinin İlk Satırları:
#    Makale_ID  Yayın_Yılı    Çalışma_Alanı     Simulasyon_Türü  \
# 0          1        2024      Tıp Eğitimi      VR Simülasyonu
# 1          2        2022    Fen Bilimleri   Sanal Lab. (PhET)
# 2          3        2025      Mühendislik        Dijital İkiz
# 3          4        2024  Kurumsal Eğitim       Ciddi Oyunlar
# 4          5        2020      Tıp Eğitimi  Fiziksel Simülatör
#
#    Bağımlı_Değişken  Etki_Büyüklüğü_(d)  \
# 0   Beceri Gelişimi                0.75
# 1  Kavramsal Anlama                0.51
# 2     Problem Çözme                0.68
# 3    İş Performansı                0.40
# 4       Karar Verme                0.82
#
#                                    Nitel_Bulgu
# 0              Operasyonel hataları azaltıyor.
# 1            Soyut kavramları somutlaştırıyor.
# 2      Kompleks sistem analizini geliştiriyor.
# 3           Eğlenceli öğrenmeyi teşvik ediyor.
# 4  Yüksek stresli ortamlara hazırlık sağlıyor.
